# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "proceedings.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""
            authors = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
                authors = authors+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = html_escape(b["publisher"].replace("{", "").replace("}","").replace("\\","")+" ")+publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"
            md += "\nauthor: '" + html_escape(authors) + "'"
            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED DBLP:conf/csonet/ChoiJNM23: " Untargeted Code Authorship Evasion with Seq2Seq Transformati ... "
# SUCESSFULLY PARSED DBLP:conf/icccn/AlkinoonAAJNM23: " Understanding the Security and Performance of the Web Presen ... "
# SUCESSFULLY PARSED DBLP:conf/ndss/KimJJMN23: " A Robust Counting Sketch for Data Plane Intrusion Detection  "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2304-13278: " Understanding the Security and ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2304-14359: " Measuring and Modeling the Fre ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2311-15366: " Untargeted Code Authorship Eva ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/access/AlikhanovJAMNN22: " Investigating the Effect of Tr ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tdsc/AbusnainaAAAJSN22: " {DL-FHMC:} Deep Learning-Based ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tmc/JangJMLN22: " A One-Page Text Entry Method O ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/ton/ParkJMM22: " A Large-Scale Behavioral Analy ... "
# SUCESSFULLY PARSED DBLP:conf/ccs/JungKJMN22: " A Scalable and Dynamic {ACL} System for In-Network Defense  "
# SUCESSFULLY PARSED DBLP:conf/cysss/AlabduljabbarMC22: " Understanding the Security of Free Content Websites by Analy ... "
# SUCESSFULLY PARSED DBLP:conf/dsn/DaoJJMN22: " Minimizing Noise in HyperLogLog-Based Spread Estimation of M ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:conf/nips/QiangPLLJZ22: " AttCAT: Explaining Transformer ... "
# SUCESSFULLY PARSED DBLP:conf/raid/AbusnainaAAAJNM22: " Systematically Evaluating the Robustness of ML-based IoT Mal ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/compsec/JungCJMN21: " A network-independent tool-bas ... "
# SUCESSFULLY PARSED DBLP:conf/dsn/AbusnainaAAAJNM21: " Systemically Evaluating the Robustness of ML-based IoT Malwa ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2108-13373: " ML-based IoT Malware Detection ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2111-02759: " Count-Less: {A} Counting Sketc ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tmc/JangKMN20: " Catch Me If You Can: Rogue Acc ... "
# SUCESSFULLY PARSED DBLP:conf/icdcs/AlasmaryAJAANM20: " Soteria: Detecting Adversarial Examples in Control Flow Grap ... "
# SUCESSFULLY PARSED DBLP:conf/infocom/JangMMMN20: " SketchFlow: Per-Flow Systematic Sampling Using Sketch Satura ... "
# SUCESSFULLY PARSED DBLP:conf/infocom/AbusnainaJKNM20: " {DFD:} Adversarial Learning-based Approach to Defend Against ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2005-07145: " A Deep Learning-based Fine-gra ... "
# SUCESSFULLY PARSED DBLP:conf/icdcs/JangMNMN19: " InstaMeasure: Instant Per-flow Detection Using Large In-DRAM ... "
# SUCESSFULLY PARSED DBLP:conf/wisec/JangMNMN19: " A cost-effective anomaly detection system using in-DRAM work ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-1902-04143: " Scaling Up Anomaly Detection U ... "
# SUCESSFULLY PARSED DBLP:conf/icdcs/JangKMN17: " Rogue Access Point Detector Using Characteristics of Channel ... "
# SUCESSFULLY PARSED DBLP:conf/infocom/JangCNN17: " RFlow\({}^{\mbox{+}}\): An SDN-based {WLAN} monitoring and m ... "
# SUCESSFULLY PARSED DBLP:conf/wisec/JangKMN17: " Highly-accurate rogue access point detection using intention ... "
# SUCESSFULLY PARSED DBLP:conf/wisec/JangCMNN17: " Two-level network monitoring and management in {WLAN} using  ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/csonet/ChoiJNM23: " Untargeted Code Authorship Eva ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/icccn/AlkinoonAAJNM23: " Understanding the Security and ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/ndss/KimJJMN23: " A Robust Counting Sketch for D ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2304-13278: " Understanding the Security and ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2304-14359: " Measuring and Modeling the Fre ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2311-15366: " Untargeted Code Authorship Eva ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/access/AlikhanovJAMNN22: " Investigating the Effect of Tr ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tdsc/AbusnainaAAAJSN22: " {DL-FHMC:} Deep Learning-Based ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tmc/JangJMLN22: " A One-Page Text Entry Method O ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/ton/ParkJMM22: " A Large-Scale Behavioral Analy ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/ccs/JungKJMN22: " A Scalable and Dynamic {ACL} S ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/cysss/AlabduljabbarMC22: " Understanding the Security of  ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/dsn/DaoJJMN22: " Minimizing Noise in HyperLogLo ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:conf/nips/QiangPLLJZ22: " AttCAT: Explaining Transformer ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/raid/AbusnainaAAAJNM22: " Systematically Evaluating the  ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/compsec/JungCJMN21: " A network-independent tool-bas ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/dsn/AbusnainaAAAJNM21: " Systemically Evaluating the Ro ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2108-13373: " ML-based IoT Malware Detection ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2111-02759: " Count-Less: {A} Counting Sketc ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/tmc/JangKMN20: " Catch Me If You Can: Rogue Acc ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/icdcs/AlasmaryAJAANM20: " Soteria: Detecting Adversarial ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/infocom/JangMMMN20: " SketchFlow: Per-Flow Systemati ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/infocom/AbusnainaJKNM20: " {DFD:} Adversarial Learning-ba ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-2005-07145: " A Deep Learning-based Fine-gra ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/icdcs/JangMNMN19: " InstaMeasure: Instant Per-flow ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/wisec/JangMNMN19: " A cost-effective anomaly detec ... "
# WARNING Missing Expected Field 'publisher' from entry DBLP:journals/corr/abs-1902-04143: " Scaling Up Anomaly Detection U ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/icdcs/JangKMN17: " Rogue Access Point Detector Us ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/infocom/JangCNN17: " RFlow\({}^{\mbox{+}}\): An SDN ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/wisec/JangKMN17: " Highly-accurate rogue access p ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/wisec/JangCMNN17: " Two-level network monitoring a ... "
